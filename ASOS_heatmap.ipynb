# %% [markdown]
# <a href="https://colab.research.google.com/github/wonkwonlee/a2w-kma-big-data-contest/blob/main/ASOS_heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 경로 설정 
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../A2W/데이터/data_submission/landslide_asos_merged.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (62,63,64,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.describe()
# Out:
#                stnId          avgTa  ...     sum_hpa      landslide
# count  102187.000000  102103.000000  ...  359.000000  102187.000000
# mean      230.230127      13.502760  ...    2.395850       0.003513
# std        63.363467       9.501431  ...    4.929499       0.059168
# min       115.000000     -16.600000  ...    0.010000       0.000000
# 25%       155.000000       5.300000  ...    0.390000       0.000000
# 50%       264.000000      14.500000  ...    1.000000       0.000000
# 75%       281.000000      21.600000  ...    2.525000       0.000000
# max       295.000000      34.100000  ...   60.900000       1.000000
#
# [8 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102187 entries, 0 to 102186
# Data columns (total 69 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   stnId           102187 non-null  int64
#  1   stnNm           102187 non-null  object
#  2   tm              102187 non-null  object
#  3   avgTa           102103 non-null  float64
#  4   minTa           102177 non-null  float64
#  5   minTaHrmt       102179 non-null  float64
#  6   maxTa           102173 non-null  float64
#  7   maxTaHrmt       102173 non-null  float64
#  8   mi10MaxRn       23532 non-null   float64
#  9   mi10MaxRnHrmt   17492 non-null   float64
#  10  hr1MaxRn        23538 non-null   float64
#  11  hr1MaxRnHrmt    18032 non-null   float64
#  12  sumRnDur        10517 non-null   float64
#  13  sumRn           35268 non-null   float64
#  14  maxInsWs        102158 non-null  float64
#  15  maxInsWsWd      102161 non-null  float64
# ...

# %%
heatmap_df = df[["avgTa","minTa","minTaHrmt","maxTa","maxTaHrmt","mi10MaxRn","mi10MaxRnHrmt","hr1MaxRn","hr1MaxRnHrmt","sumRnDur","sumRn",
                 "maxInsWs","maxInsWsWd","maxInsWsHrmt","maxWs","maxWsWd","maxWsHrmt","avgWs","hr24SumRws","maxWd","avgTd","minRhm","minRhmHrmt",	
                 "avgRhm","avgPv","avgPa","maxPs","maxPsHrmt","minPs","minPsHrmt","avgPs","ssDur","sumSsHr","hr1MaxIcsrHrmt","hr1MaxIcsr",
                 "sumGsr","ddMefs","ddMefsHrmt","ddMes","ddMesHrmt","sumDpthFhsc","avgTca","avgLmac","avgTs","minTg","avgCm5Te","avgCm10Te",
                 "avgCm20Te","avgCm30Te","avgM05Te","avgM10Te","avgM15Te","avgM30Te","avgM50Te","sumLrgEv","sumSmlEv","n99Rn","landslide"]]


colormap = plt.cm.PuBu
plt.figure(figsize=(30, 20))
plt.title("Heatmap Correlation of Features", size = 20)
sns.heatmap(heatmap_df.astype(float).corr(), linewidths = 0.1, vmax = 1.0, 
            square = True, cmap = colormap, linecolor = "white")

# %%
heatmap_df.corr()
# Out:
#                    avgTa     minTa  minTaHrmt  ...  sumSmlEv     n99Rn  landslide
# avgTa           1.000000  0.974692  -0.093551  ...  0.522404  0.146616   0.052289
# minTa           0.974692  1.000000  -0.042643  ...  0.412743  0.167150   0.064052
# minTaHrmt      -0.093551 -0.042643   1.000000  ... -0.143767  0.077991   0.045385
# maxTa           0.970318  0.901626  -0.137450  ...  0.600305  0.110685   0.035408
# maxTaHrmt       0.004949 -0.048387  -0.302592  ...  0.167190 -0.121136  -0.045779
# mi10MaxRn       0.181367  0.221696   0.057938  ... -0.162652  0.552748   0.355305
# mi10MaxRnHrmt   0.060498  0.016362  -0.043800  ... -0.041694  0.159700  -0.055140
# hr1MaxRn        0.112537  0.166887   0.070210  ... -0.213761  0.645090   0.477898
# hr1MaxRnHrmt    0.037831 -0.001878  -0.033740  ... -0.061965  0.162151  -0.054433
# sumRnDur       -0.126431 -0.048371   0.080436  ... -0.506132  0.433646   0.144011
# ...

# %%
is_landslide = df['landslide'] == 1
df_landslide = df[is_landslide]
df_landslide
# Out:
#        stnId stnNm          tm  avgTa  ...  location  sum_cnt  sum_hpa  landslide
# 5863     138    포항  2011-07-09   24.0  ...    포항 죽장면      1.0     0.18        1.0
# 5866     155    창원  2011-07-09   23.6  ...    창원 구산면      1.0     0.30        1.0
# 5867     155    창원  2011-07-09   23.6  ...    창원 완월동      1.0     0.08        1.0
# 5870     192    진주  2011-07-09   22.7  ...    사천 곤명면      1.0     1.00        1.0
# 5871     192    진주  2011-07-09   22.7  ...    사천 곤양면      1.0     1.00        1.0
# ...      ...   ...         ...    ...  ...       ...      ...      ...        ...
# 99421    285    합천  2019-10-03   23.3  ...    고령 쌍림면      1.0     4.40        1.0
# 99422    285    합천  2019-10-03   23.3  ...    고령 우곡면      1.0     0.52        1.0
# 99423    288    밀양  2019-10-03   23.4  ...    밀양 무안면      1.0     0.28        1.0
# 99424    288    밀양  2019-10-03   23.4  ...    창녕 영산면      1.0     0.13        1.0
# ...

# %%
heatmap_df_landslide = df[["avgTa","minTa","minTaHrmt","maxTa","maxTaHrmt","mi10MaxRn","mi10MaxRnHrmt","hr1MaxRn","hr1MaxRnHrmt","sumRnDur",
                           "sumRn","maxInsWs","maxInsWsWd","maxInsWsHrmt","maxWs","maxWsWd","maxWsHrmt","avgWs","hr24SumRws","maxWd","avgTd",
                           "minRhm","minRhmHrmt",	"avgRhm","avgPv","avgPa","maxPs","maxPsHrmt","minPs","minPsHrmt","avgPs","ssDur","sumSsHr",
                           "hr1MaxIcsrHrmt","hr1MaxIcsr","sumGsr","ddMefs","ddMefsHrmt","ddMes","ddMesHrmt","sumDpthFhsc","avgTca","avgLmac",
                           "avgTs","minTg","avgCm5Te","avgCm10Te","avgCm20Te","avgCm30Te","avgM05Te","avgM10Te","avgM15Te","avgM30Te",
                           "avgM50Te","sumLrgEv","sumSmlEv","n99Rn","landslide"]]


colormap = plt.cm.PuBu
plt.figure(figsize=(30, 20))
plt.title("Heatmap Correlation of Features 2", size = 20)
sns.heatmap(heatmap_df_landslide.astype(float).corr(), linewidths = 0.1, vmax = 1.0, 
            square = True, cmap = colormap, linecolor = "white")

# %%
heatmap_df_landslide.corr()
# Out:
#                    avgTa     minTa  minTaHrmt  ...  sumSmlEv     n99Rn  landslide
# avgTa           1.000000  0.974692  -0.093551  ...  0.522404  0.146616   0.052289
# minTa           0.974692  1.000000  -0.042643  ...  0.412743  0.167150   0.064052
# minTaHrmt      -0.093551 -0.042643   1.000000  ... -0.143767  0.077991   0.045385
# maxTa           0.970318  0.901626  -0.137450  ...  0.600305  0.110685   0.035408
# maxTaHrmt       0.004949 -0.048387  -0.302592  ...  0.167190 -0.121136  -0.045779
# mi10MaxRn       0.181367  0.221696   0.057938  ... -0.162652  0.552748   0.355305
# mi10MaxRnHrmt   0.060498  0.016362  -0.043800  ... -0.041694  0.159700  -0.055140
# hr1MaxRn        0.112537  0.166887   0.070210  ... -0.213761  0.645090   0.477898
# hr1MaxRnHrmt    0.037831 -0.001878  -0.033740  ... -0.061965  0.162151  -0.054433
# sumRnDur       -0.126431 -0.048371   0.080436  ... -0.506132  0.433646   0.144011
# ...

# %% [markdown]
# # 칼럼 전처리 및 결측값 제거
# * stnId - 지점 번호, 102187
# * stnNm - 지점명, 102187
# * tm - 시간, 102187
# * avgTa - 평균 기온, 102103
# * minTa - 최저 기온, 102177
# * minTaHrmt - 최저 기온 시각, 102179
# * maxTa - 최고 기온, 102173
# * maxTaHrmt - 최고 기온 시각, 102173
# * mi10MaxRn - 10분 최다강수량, 23532
# * mi10MaxRnHrmt - 10분 최다강수량 시각, 17492
# * hr1MaxRn - 1시간 최다강수량, 23538
# * hr1MaxRnHrmt - 1시간 최다강수량 시각, 18032
# * sumRnDur - 강수 계속 시간, 10517
# * sumRn - 일 강수량, 35268
# * maxInsWs - 최대 순간풍속, 102158
# * maxInsWsWd - 최대 순간풍속 풍향, 102161
# * maxInsWsHrmt - 최대 순간풍속 시각, 102161
# * maxWs - 최대 풍속, 102152
# * maxWsWd - 최대 풍속 풍향, 102161
# * maxWsHrmt - 최대 풍속 풍향, 102161
# * avgWs - 평균 풍속, 102120
# * hr24SumRws - 풍정합, 102115
# * maxWd - 최다 풍향, 101895
# * avgTd	- 평균 이슬점온도, 102031
# * minRhm - 최소 상대습도, 102115
# * minRhmHrmt - 평균 상대습도 시각, 102116
# * avgRhm - 평균 상대습도, 102015
# * avgPv - 평균 증기압, 102022
# * avgPa - 평균 현지기압, 102073
# * maxPs - 최고 해면기압, 102144
# * maxPsHrmt - 최고 해면기압 시각, 102149
# * minPs - 최저 해면기압, 102144
# * minPsHrmt - 최저 해면기압 시각, 102149
# * avgPs - 평균 해면기압, 102075
# * ssDur - 가조시간, 102177
# * sumSsHr - 합계 일조 시간, 101992
# * hr1MaxIcsrHrmt - 1시간 최다 일사 시각, 41974
# * hr1MaxIcsr - 1시간 최다 일사량, 41965
# * sumGsr - 합계 일사량, 41966
# * ddMefs - 일 최심신적설, 687
# * ddMefsHrmt - 일 최심신적설 시각, 754
# * ddMes - 일 최심적설, 1306
# * ddMesHrmt - 일 최심적설 시각, 1300
# * sumDpthFhsc - 합계 3시간 신적설, 811
# * avgTca - 평균 지면온도, 41693
# * avgLmac - 평균 중하층운량, 40313
# * avgTs - 평균 지면온도, 102112
# * minTg - 최저 초상온도, 102110
# * avgCm5Te - 평균 5cm 지중온도, 35467
# * avgCm10Te - 평균 10cm 지중온도, 35425
# * avgCm20Te - 평균 20cm 지중온도, 35493
# * avgCm30Te - 평균 30cm 지중온도, 35467
# * avgM05Te - 0.5m 지중온도, 12501
# * avgM10Te - 1.0m 지중온도, 12506
# * avgM15Te - 1.5m 지중온도, 9874
# * avgM30Te - 3.0m 지중온도, 9872
# * avgM50Te - 5.0m 지중온도, 9870
# * sumLrgEv - 합계 대형증발량, 23268
# * sumSmlEv - 합계 소형증발량, 27380
# * n99Rn - 9-9 강수, 6314
# * iscs - 일기현상, 17919
# * sumFogDur - 안개 계속 시간, 1689
#
#
# **전체 데이터 행 102187**

# %% [markdown]
# # 1. 시각(Hrmt) 데이터 및 일기현상(iscs) 전부 삭제

# %%
# 필요없는 열 제거
df_refined = df.drop(['minTaHrmt','maxTaHrmt','mi10MaxRnHrmt','hr1MaxRnHrmt','maxInsWsHrmt','maxWsHrmt','minRhmHrmt','maxPsHrmt',
                      'minPsHrmt','hr1MaxIcsrHrmt','ddMefsHrmt','ddMesHrmt','iscs'], axis=1)
df_refined
# Out:
#         stnId stnNm          tm  avgTa  ...  location  sum_cnt  sum_hpa  landslide
# 0         115   울릉도  2011-01-01    0.8  ...       NaN      NaN      NaN        0.0
# 1         130    울진  2011-01-01   -1.0  ...       NaN      NaN      NaN        0.0
# 2         136    안동  2011-01-01   -4.5  ...       NaN      NaN      NaN        0.0
# 3         137    상주  2011-01-01   -5.2  ...       NaN      NaN      NaN        0.0
# 4         138    포항  2011-01-01   -0.6  ...       NaN      NaN      NaN        0.0
# ...       ...   ...         ...    ...  ...       ...      ...      ...        ...
# 102182    285    합천  2019-12-31   -1.5  ...       NaN      NaN      NaN        0.0
# 102183    288    밀양  2019-12-31   -1.1  ...       NaN      NaN      NaN        0.0
# 102184    289    산청  2019-12-31   -2.5  ...       NaN      NaN      NaN        0.0
# 102185    294    거제  2019-12-31    0.7  ...       NaN      NaN      NaN        0.0
# ...

# %% [markdown]
# # 2. 일조, 기압, 운량, 지중온도, 안개 데이터 삭제
#
# 전운량 - 구름량

# %%
df_refined = df_refined.drop(['avgPv','avgPa','maxPs','minPs','avgPs','ssDur','sumSsHr','hr1MaxIcsr',
                              'avgTca','avgLmac','avgCm5Te','avgCm10Te','avgCm20Te','avgCm30Te','avgM05Te',
                              'avgM10Te','avgM15Te','avgM30Te','avgM50Te','sumFogDur'], axis=1)

# %%
df_refined.columns
# Out:
# Index(['stnId', 'stnNm', 'tm', 'avgTa', 'minTa', 'maxTa', 'mi10MaxRn',
#        'hr1MaxRn', 'sumRnDur', 'sumRn', 'maxInsWs', 'maxInsWsWd', 'maxWs',
#        'maxWsWd', 'avgWs', 'hr24SumRws', 'maxWd', 'avgTd', 'minRhm', 'avgRhm',
#        'sumGsr', 'ddMefs', 'ddMes', 'sumDpthFhsc', 'avgTs', 'minTg',
#        'sumLrgEv', 'sumSmlEv', 'n99Rn', 'sd', 'sgg', 'umd', 'location',
#        'sum_cnt', 'sum_hpa', 'landslide'],
#       dtype='object')

# %% [markdown]
# # 3. 풍향, 이슬점 데이터 삭제
# 풍향, 풍정합, 이슬점 온도

# %%
df_refined = df_refined.drop(['maxInsWsWd','maxWsWd','hr24SumRws','maxWd','avgTd'], axis=1)
df_refined.columns
# Out:
# Index(['stnId', 'stnNm', 'tm', 'avgTa', 'minTa', 'maxTa', 'mi10MaxRn',
#        'hr1MaxRn', 'sumRnDur', 'sumRn', 'maxInsWs', 'maxWs', 'avgWs', 'minRhm',
#        'avgRhm', 'sumGsr', 'ddMefs', 'ddMes', 'sumDpthFhsc', 'avgTs', 'minTg',
#        'sumLrgEv', 'sumSmlEv', 'n99Rn', 'sd', 'sgg', 'umd', 'location',
#        'sum_cnt', 'sum_hpa', 'landslide'],
#       dtype='object')

# %% [markdown]
# # 현재 남은 변수
# * avgTa 평균 기온
# * minTa 최저 기온
# * maxTa 최고 기온
# * mi10MaxRn 10분 최다 강수량
# * hr1MaxRn 1시간 최다 강수량
# * sumRnDur 강수 계속 시간
# * sumRn 일 강수량
# * maxInsWs 최대 순간풍속
# * maxWs 최대 풍속
# * avgWs 평균 풍속
# * minRhm 최소 상대습도
# * avgRhm 평균 상대습도
# * sumGsr 합계 일사량
# * ddMefs 일 최심신적설
# * ddMes 일 최심적설
# * sumDpthFhsc 합계 3시간 신적설
# * avgTs 평균 지면온도
# * minTg 최저 초상온도
# * sumLrgEv 합계 대형증발량
# * sumSmlEv 합계 소형증발량
# * n99Rn 9-9 강수
#
#
# # 상관관계 및 Heatmap
# 남은 변수들을 이용해 새로운 상관계수 표 및 히트맵을 만들어 변수의 중요도를 파악한다

# %%
heatmap_refined = df[['avgTa', 'minTa', 'maxTa', 'mi10MaxRn', 'hr1MaxRn', 'sumRnDur', 'sumRn', 
                      'maxInsWs', 'maxWs', 'avgWs', 'minRhm','avgRhm', 'sumGsr', 'ddMefs', 'ddMes', 
                      'sumDpthFhsc', 'avgTs', 'minTg','sumLrgEv', 'sumSmlEv', 'n99Rn','landslide']]


colormap = plt.cm.PuBu
plt.figure(figsize=(30, 20))
plt.title("Heatmap Correlation of Features", size = 20)
sns.heatmap(heatmap_refined.astype(float).corr(), linewidths = 0.1, vmax = 1.0, 
            square = True, cmap = colormap, annot=True, linecolor = "white")

# %%
heatmap_refined.corr()
# Out:
#                 avgTa     minTa     maxTa  ...  sumSmlEv     n99Rn  landslide
# avgTa        1.000000  0.974692  0.970318  ...  0.522404  0.146616   0.052289
# minTa        0.974692  1.000000  0.901626  ...  0.412743  0.167150   0.064052
# maxTa        0.970318  0.901626  1.000000  ...  0.600305  0.110685   0.035408
# mi10MaxRn    0.181367  0.221696  0.126839  ... -0.162652  0.552748   0.355305
# hr1MaxRn     0.112537  0.166887  0.045127  ... -0.213761  0.645090   0.477898
# sumRnDur    -0.126431 -0.048371 -0.208595  ... -0.506132  0.433646   0.144011
# sumRn        0.157865  0.200411  0.099664  ... -0.207508  0.839515   0.525296
# maxInsWs    -0.177861 -0.143035 -0.227066  ...  0.044169  0.056312   0.091491
# maxWs       -0.175068 -0.142495 -0.219451  ...  0.074145  0.047160   0.089190
# avgWs       -0.153394 -0.095599 -0.229038  ...  0.085495  0.024053   0.052911
# minRhm       0.449929  0.564879  0.298090  ... -0.308066  0.288438   0.093254
# ...

# %% [markdown]
# # 히트맵/상관계수 분석 결과
# * 분석 결과 적설량 데이터는 상관계수가 NaN임을 보아 산사태와 눈은 상관이 없기에 제거한다. (ddMefs, ddMes, sumDpthFhsc)
# * 온도 또한 큰 상관이 없음으로 제거한다.
#   + ASOS 데이터의 평균, 최저, 최고 기온을 제외한 평균 지면온도 (avgTs), 최저 초상온도 (minTg) 제거
# * 증발량 데이터 또한 상관계수가 대형 -0.05, 소형 -0.04 이므로 산사태 발생에 유의미한 변수가 되지 못한다고 판단하여 제거한다.
# * 합계 일사량 또한 제거한다. (sumGsr)

# %%
df_refined = df_refined.drop(['ddMefs','ddMes','sumDpthFhsc','avgTs','minTg','sumGsr','sumLrgEv','sumSmlEv'], axis=1)
df_refined.columns
# Out:
# Index(['stnId', 'stnNm', 'tm', 'avgTa', 'minTa', 'maxTa', 'mi10MaxRn',
#        'hr1MaxRn', 'sumRnDur', 'sumRn', 'maxInsWs', 'maxWs', 'avgWs', 'minRhm',
#        'avgRhm', 'n99Rn', 'sd', 'sgg', 'umd', 'location', 'sum_cnt', 'sum_hpa',
#        'landslide'],
#       dtype='object')

# %% [markdown]
# # 히트맵 분석 2
# 전처리한 데이터를 가지고 새롭게 히트맵과 상관계수를 분석해본다.
#
# 또한 현재까지 만들어진 데이터프레임을 csv로 새롭게 저장한다

# %%
heatmap_refined = df[['avgTa', 'minTa', 'maxTa', 'mi10MaxRn',
                      'hr1MaxRn', 'sumRnDur', 'sumRn', 'maxInsWs', 'maxWs', 'avgWs', 'minRhm',
                      'avgRhm', 'n99Rn', 'landslide']]


colormap = plt.cm.PuBu
plt.figure(figsize=(20, 15))
plt.title("Heatmap Correlation of Features", size = 20)
sns.heatmap(heatmap_refined.astype(float).corr(), linewidths = 0.1, vmax = 1.0, 
            square = True, cmap = colormap, annot=True, linecolor = "white")

# %%
df_refined.to_csv('ASOS_temp.csv',index=False, encoding='utf-8-sig')

# %% [markdown]
# # 결측값 처리
